# %%
import pandas as pd

path = "C:\\Users\\dmehri\\Documents\\DATA\\Applied Data Science Coursera\\Course 4 Text Mining\\"

doc = []
with open(path + 'dates.txt') as file:
    for line in file:
        doc.append(line)

df = pd.Series(doc)
df.head()

#df_out = pd.DataFrame(doc)

#df_out.to_csv(path + "datesdf.csv", index=False)
# Out:
# 0         03/25/93 Total time of visit (in minutes):\n
# 1                       6/18/85 Primary Care Doctor:\n
# 2    sshe plans to move as of 7/8/71 In-Home Servic...
# 3                7 on 9/27/75 Audit C Score Current:\n
# 4    2/6/96 sleep studyPain Treatment Pain Level (N...
# dtype: object

# %%
df[0]

# %%
def date_sorter():
    import re
    import pandas as pd
    
    doc = []
    with open(path + 'dates.txt') as file:
        for line in file:
            doc.append(line)

    df = pd.Series(doc)
   
    
    
    df = pd.DataFrame(df)
    
    df["DateStr"] = ""
    
    # Your code here
    
    date_list = []
    
    for i in range(0, len(df)):
        #s = df[i]
        s = df[0][i]
        
        s = s.replace(",", "")
        s = s.replace(".","")
        s = s.replace("December","Dec")
        s = s.replace("Decemeber","Dec")
        s = s.replace("January","Jan")
        s = s.replace("Janaury","Jan")
        s = s.replace("February","Feb")
        s = s.replace("March","Mar")
        s = s.replace("April","Apr")
        s = s.replace("June","Jun")
        s = s.replace("July","Jul")
        s = s.replace("August","Aug")
        s = s.replace("September","Sep")
        s = s.replace("October","Oct")
        s = s.replace("November","Nov")
        
        date_str = re.findall(r'\d{1,2}[/-]\d{1,2}[/-]\d{2,4}', s)
        
        if len(date_str) == 0:
            date_str = re.findall(r'(?:\d{2} )?(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]* (?:\d{2}, )?\d{4}', s)
            
        if len(date_str) == 0:
            date_str = re.findall(r'(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]* \d{2} \d{2,4}', s)
            
        #format: 6/1998
        if len(date_str) == 0:
            date_str = re.findall(r'\d{1,2}[/]\d{4}', s)
            
        if len(date_str) == 0:
            date_str = re.findall(r'\d{4}', s)
            
            
        if len(date_str) > 0:
            date_list.append(date_str)
            
        #print (date_str)
            
        df["DateStr"][i] = date_str[0]
    
    dateDic = {"Jan": "1", "Feb":"2", "Mar":"3", "Apr":"4", "May":"5", "Jun":"6", "Jul":"7", "Aug":"8", "Sep":"9",
              "Oct":"10", "Nov":"11", "Dec":"12"}
    
    def DateCorr(s2,thedate):
        #print (s2)
        s2 = s2.replace(thedate, "")
        s2 = dateDic[thedate] + " " + s2
        s2 = s2.replace("  ", " ")
        s2 = s2.replace(" ", "/")
        #print (s2)
        #print ()
        return s2
    
    
    for i in range(0, len(df)):
        s2 = df["DateStr"][i]
        if "Jan" in s2:
            thedate = "Jan"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2
        
        if "Feb" in s2:
            thedate = "Feb"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2
        if "Mar" in s2:
            thedate = "Mar"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2
        if "Apr" in s2:
            thedate = "Apr"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2
        if "May" in s2:
            thedate = "May"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2   
        if "Jun" in s2:
            thedate = "Jun"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2     
        if "Jul" in s2:
            thedate = "Jul"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2  
        if "Aug" in s2:
            thedate = "Aug"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2  
        if "Sep" in s2:
            thedate = "Sep"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2    
        if "Oct" in s2:
            thedate = "Oct"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2      
        if "Nov" in s2:
            thedate = "Nov"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2     
        if "Dec" in s2:
            thedate = "Dec"
            s2 = DateCorr(s2, thedate)
            df["DateStr"][i] = s2  
               
            
        #print (s)
        #print (date_str)
        
    
    #print ("len of df", len(df) )
    #print ("len of date_list", len(date_list))
    
    
    
    df['DateStr'] = pd.to_datetime(df['DateStr'])
    df['DateStr'] = df['DateStr'].apply(lambda x: x.date())
    
   
    
    df["Index"] = df.index
    
    df = df[[0, "Index", "DateStr"]]
    df = df.sort_values(by = 'DateStr', ascending=True).reset_index(drop=True)
    #df.to_csv(path + "datesdf2.csv", index=False)
    #print (df)
    series = pd.Series(df['Index'], index=df.index)
    
    return df

date_sorter()
# Out:
#                                                      0  Index     DateStr
# 0             (4/10/71)Score-1Audit C Score Current:\n      9  1971-04-10
# 1          5/18/71 Total time of visit (in minutes):\n     84  1971-05-18
# 2    sshe plans to move as of 7/8/71 In-Home Servic...      2  1971-07-08
# 3                        7/11/71 SOS-10 Total Score:\n     53  1971-07-11
# 4                               9/12/71 [report_end]\n     28  1971-09-12
# 5    sPatient reported losing three friends that pa...    474  1972-01-01
# 6                   13 Jan 1972 Primary Care Doctor:\n    153  1972-01-13
# 7    1/26/72 Communication with referring physician...     13  1972-01-26
# 8                    06 May 1972 SOS-10 Total Score:\n    129  1972-05-06
# 9    5/13/72 Other Adult Mental Health Outcomes Sca...     98  1972-05-13
# 10                       6/10/72 SOS-10 Total Score:\n    111  1972-06-10
# 11   June 15, 1972 Family Psych History: Family His...    225  1972-06-15
# ...

# %%
df2.to_csv(path + "datesdf.csv", index=False)

# %%
path
